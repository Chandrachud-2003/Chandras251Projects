# %% [markdown]
# # Extension 3 - Confidence intervals on linear regression plots

# %% [markdown]
# - Add the option to plot 95% confidence intervals on the linear regression predictions in your plot functions (e.g. `scatter`). [This website](https://real-statistics.com/regression/confidence-and-prediction-intervals/) should be a helpful reference.

# %%
# Importing the required stuff

import os
import random
import numpy as np
import matplotlib.pyplot as plt

from data import Data
from linear_regression import LinearRegression

plt.style.use(['seaborn-v0_8-colorblind', 'seaborn-v0_8-darkgrid'])
plt.rcParams.update({'font.size': 20})

np.set_printoptions(suppress=True, precision=5)

# Automatically reload external modules
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Plotting the regular scatterplot without confidence intervals

# %%
# Getting the filename for polynomial data
filename = os.path.join('data', 'poly.csv')

# Fit the poly_data.csv data using a polynomial regression where p = 1
poly_reg = LinearRegression(Data('data/poly_data.csv'))
poly_reg.linear_regression(ind_vars=['X'], dep_var='Y', p=1)

# Use scatter of the regression data
poly_reg.scatter('X', 'Y', f'Polynomial Regression (p=1), MSE: {poly_reg.mse:.2f}')

# print out the mse 
print(f'MSE: {poly_reg.mse}')
# Print the r^2 value
print(f'R^2: {poly_reg.R2}')
# Out:
# MSE: 71.81095284569933
# R^2: 0.6932566071471753

# %%
# Getting the filename for polynomial data
filename = os.path.join('data', 'poly.csv')

# Fit the poly_data.csv data using a polynomial regression where p = 1
poly_reg = LinearRegression(Data('data/poly_data.csv'))
poly_reg.linear_regression(ind_vars=['X'], dep_var='Y', p=1)

# Use scatter of the regression data
poly_reg.scatter('X', 'Y', f'Polynomial Regression (p=1), MSE: {poly_reg.mse:.2f}', display_ci=True)

# print out the mse 
print(f'MSE: {poly_reg.mse}')
# Print the r^2 value
print(f'R^2: {poly_reg.R2}')
# Out:
# MSE: 71.81095284569933
# R^2: 0.6932566071471753

# %% [markdown]
# # Discussion

# %% [markdown]
# Extension: Confidence intervals on linear regression plots
#
# In this extension, I added the option to plot 95% confidence intervals on the linear regression predictions in the plot functions, using the display_ci parameter in the scatter() function. The 95% confidence interval was calculated using the t-distribution. The reference used for this extension was the following website: https://real-statistics.com/regression/confidence-and-prediction-intervals/.
#
# To visualize the results of this extension, I displayed examples of plots with and without confidence intervals. The dataset used is the poly_data.csv dataset from the original project. The polynomial regression for this dataset was previously calculated for p=1, and the regression scatter plot will be used as an example for the purpose of this extension.
#
# In this example, we can see that the red line representing the regression prediction has confidence intervals in grey added to it. This gives us an idea of the range of possible values for each x value based on our regression model.
#
# Overall, this extension provides more information on the regression model and is a useful addition to the original project.
