# %% [markdown]
# # Extension 3 - More datasets
#
# For this extension, I analyzed an additional dataset - the Penguins.csv dataset from Seaborn

# %% [markdown]
# ## What is the Seaborn Penguins Dataset?
#
# The penguins.csv dataset is a popular dataset from the Seaborn library that contains information on various physical characteristics of three penguin species, collected from the Palmer Station Long Term Ecological Research (LTER) program in Antarctica. The dataset contains the following variables:
#
# 1. species: The species of the penguin (Adelie, Chinstrap, or Gentoo)
#
# 2. island: The island on which the penguin was observed (Biscoe, Dream, or Torgersen)
#
# 3. bill_length_mm: The length of the penguin's bill in millimeters (mm)
#
# 4. bill_depth_mm: The depth of the penguin's bill in millimeters (mm)
#
# 5. flipper_length_mm: The length of the penguin's flipper in millimeters (mm)
#
# 6. body_mass_g: The body mass of the penguin in grams (g)
#
# 7. sex: The sex of the penguin (Male or Female)
#
# 8. year: The year in which the observation was made (2007 or 2009)
#
# These variables provide information on various physical characteristics of the penguins, such as their size, weight, and sex, and can be used to explore patterns and relationships between the different penguin species.

# %%
# Importing libraries
from data import Data
import numpy as np
from analysis import Analysis
import matplotlib.pyplot as plt

# Fixing the diamonds csv file
penguins_filename = 'data/penguins.csv'

# Creating a data object
penguins_data = Data(penguins_filename)

# Exploring the data

# Creating an analysis object
penguins_an = Analysis(penguins_data)

# Getting the headers
penguins_headers = penguins_data.get_headers()
print(f'The dataset headers are {penguins_headers}')

# Getting the data
penguins_data = penguins_data.get_all_data()
print(f'The numeric data is \n{penguins_data}')

# Getting the shape of the data
penguins_shape = penguins_data.shape
print(f'Your shape is {penguins_data} and should be (344, 3)')

# Getting the number of rows
penguins_num_rows = penguins_data.shape[0]
print(f'Your number of rows is {penguins_num_rows} and should be 344')

# Getting the number of columns
penguins_num_cols = penguins_data.shape[1]
print(f'Your number of columns is {penguins_num_cols} and should be 4')

# Finding the min
penguins_min = penguins_an.min(penguins_headers)
print(f'Your min is {penguins_min}')

# Finding the max
penguins_max = penguins_an.max(penguins_headers)
print(f'Your max is {penguins_max}')

# Finding the mean
penguins_mean = penguins_an.mean(penguins_headers)
print(f'Your mean is {penguins_mean}')

# Finding the standard deviation
penguins_std = penguins_an.std(penguins_headers)
print(f'Your standard deviation is {penguins_std}')

# Finding the variance
penguins_var = penguins_an.var(penguins_headers)
print(f'Your variance is {penguins_var}')

# Plotting a scatterplot with bill length vs flipper length
x_samps, y_samps = penguins_an.scatter('bill_length_mm', 'flipper_length_mm', 'Flipper Length vs. Bill Length')
penguins_an.show()

print(f'Your x sample shape is {x_samps.shape} and should be (344,)')
print(f'Your y sample shape is {y_samps.shape} and should be (344,)')

# Plotting a scatterplot with body mass vs bill length
x_samps, y_samps = penguins_an.scatter('body_mass_g', 'bill_length_mm', 'Bill Length vs. Body Mass')
penguins_an.show()


print(f'Your x sample shape is {x_samps.shape} and should be (344,)')
print(f'Your y sample shape is {y_samps.shape} and should be (344,)')

# Plotting a pair plot
fig, axes = penguins_an.pair_plot(penguins_headers, (10, 10), 'Pair Plot of Penguins Data')
penguins_an.show()

print(f'Do you have a 4 X 4 grid of plots? {axes.shape[0] == 4 and axes.shape[1] == 4}')
# Out:
# The dataset headers are ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']
# The numeric data is
# [[  39.1   18.7  181.  3750. ]
#  [  39.5   17.4  186.  3800. ]
#  [  40.3   18.   195.  3250. ]
#  ...
#  [  50.4   15.7  222.  5750. ]
#  [  45.2   14.8  212.  5200. ]
#  [  49.9   16.1  213.  5400. ]]
# Your shape is [[  39.1   18.7  181.  3750. ]
#  [  39.5   17.4  186.  3800. ]
#  [  40.3   18.   195.  3250. ]
#  ...
#  [  50.4   15.7  222.  5750. ]
#  [  45.2   14.8  212.  5200. ]
#  [  49.9   16.1  213.  5400. ]] and should be (344, 3)
# Your number of rows is 344 and should be 344
# Your number of columns is 4 and should be 4
# Your min is [0. 0. 0. 0.]
# Your max is [  59.6   21.5  231.  6300. ]
# Your mean is [  43.66656977   17.05145349  199.74709302 4177.3255814 ]
# Your standard deviation is [  6.38877604   2.36269555  20.75056619 861.23494208]
# Your variance is [4.08164593e+01 5.58233024e+00 4.30585997e+02 7.41725625e+05]
# ...

# %% [markdown]
# # Findings from the Penguin Dataset
#
# ## Data Object:
#
# The penguins dataset from Kaggle was used for this analysis. The dataset consists of physical measurements (bill length, bill depth, flipper length, and body mass) of penguins from three different species (Adelie, Chinstrap, and Gentoo) from the Palmer Archipelago, Antarctica.
#
# ## Data Analysis:
#
# The dataset consists of 344 rows and 4 columns, with headers 'bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', and 'body_mass_g'. All columns have numeric data.
#
# After analyzing the dataset, it was found that the minimum values for each of the columns are 0, and the maximum values are [59.6, 21.5, 231, 6300] for 'bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', and 'body_mass_g' respectively. The mean values for each of the columns are [43.67, 17.05, 199.75, 4177.33], and the standard deviation values are [6.39, 2.36, 20.75, 861.23]. The variance values for each of the columns are [41.82, 5.58, 430.59, 741725.63].
#
# Scatter plots were created to visualize the relationship between different variables. A scatter plot of 'Flipper Length vs. Bill Length' showed a clear positive correlation between the two variables. On the other hand, a scatter plot of 'Bill Length vs. Body Mass' did not show a clear relationship between the two variables.
#
# A pair plot was also created to visualize the relationship between all the variables in the dataset. The pair plot showed strong positive correlations between 'Flipper Length vs. Body Mass' and 'Flipper Length vs. Bill Length'. However, there was no clear relationship between 'Bill Depth vs. Body Mass' and 'Bill Depth vs. Bill Length'.
#
# ## Hypotheses:
#
# ### Penguins with longer bills will have a higher body mass.
#
# To test this hypothesis, a scatter plot of 'Bill Length vs. Body Mass' was created. However, the scatter plot did not show a clear relationship between the two variables, so the hypothesis cannot be proven.
#
# ### Penguins with longer flippers will have a higher body mass.
# To test this hypothesis, a scatter plot of 'Flipper Length vs. Body Mass' was created. The scatter plot showed a strong positive correlation between the two variables, which supports the hypothesis.
#
# ## Conclusion:
#
# The penguins dataset provided valuable insights into the physical characteristics of different penguin species. The pair plot showed strong positive correlations between 'Flipper Length vs. Body Mass' and 'Flipper Length vs. Bill Length', indicating that these physical characteristics are closely related. The scatter plot of 'Flipper Length vs. Bill Length' also showed a clear positive correlation between the two variables.
#
# Based on the findings, it can be concluded that the size and shape of penguins' flippers are closely related to their body mass, which can have important implications for their survival and adaptation to their environment. However, the relationship between bill length and body mass is not as clear and requires further investigation. Overall, the findings of this analysis can be useful for researchers and conservationists studying penguin populations and their physical adaptations.
