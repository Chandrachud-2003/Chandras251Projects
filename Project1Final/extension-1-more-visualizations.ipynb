# %% [markdown]
# # Extension 1 - More visualizations
#
# For this extension, I created the following additional visualizations using various types of charts and graphs:
#
# 1. Box plots: Box plots can show the distribution of each variable and identify any outliers or unusual values. They can be particularly useful for variables like price and carat weight, which may have a large range of values.
#
# 2. Histograms: Histograms can help show the distribution of a single variable. They can be used to show the distribution of carat weight, price, and other numeric variables.
#
# 3. Heatmap: A heatmap can show the correlation matrix of the dataset, allowing for an easy visual identification of strong correlations between variables.
#
# 4. 3D scatterplot: A 3D scatterplot can provide a visual representation of how three variables relate to one another. For example, we can plot the carat weight on the x-axis, the depth on the y-axis, and the price on the z-axis.
#
# 5. Density plot: A density plot can be used to show the distribution of a variable, similar to a histogram. However, it can be more useful in cases where there are multiple overlapping distributions, as it can show each distribution separately.

# %%
# Importing the diamonds.csv dataset

# Importing libraries
from data import Data
import numpy as np
import pandas as pd
from analysis_extension_1 import Analysis
import matplotlib.pyplot as plt

# Fixing the diamonds csv file
diamonds_filename = 'data/diamonds.csv'

# Creating a data object
diamonds_data = Data(diamonds_filename)

# Exploring the data

# Creating an analysis object
diamonds_an = Analysis(diamonds_data)

# %%
# Plotting boxplots for the diamonds dataset
diamonds_an.boxplot(['carat', 'price'])
plt.show()

# %%
# Plotting histograms for the diamonds dataset
diamonds_an.histogram(['carat', 'price'])
plt.show()

# %%
# Creating 3D scatterplots for the diamonds dataset
diamonds_an.scatter3d(['carat', 'price', 'depth'])
plt.show()

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Creating a heatmap for the diamonds dataset
diamonds_an.heatmap(['carat', 'price', 'depth'])
plt.show()

# %%
# Creating density plots for the diamonds dataset
diamonds_an.density(['carat', 'price'])
plt.show()

# %% [markdown]
# # Findings:
#
# ## Introduction:
#
# For this extension, I implemented various additional visualization techniques such as box plots, histograms, 3D scatter plots, heat maps, and density plots. These techniques will help  to gain insights into the dataset and identify patterns and relationships among the variables.
#
# ## Implementation of Visualization techniques:
#
# We have used the Data and Analysis classes to read and analyze the diamonds dataset. The Data class reads the dataset from the CSV file and provides various methods to manipulate the data. The analysis_extension_1.py file contains various additional methods for visualization, including box plots, histograms, 3D scatter plots, heat maps, and density plots.
#
# ## Exploration of the Data:
#
# The diamonds dataset contains information about the characteristics of diamonds, including carat, cut, color, clarity, depth, table, price, and dimensions. The dataset contains 53,940 records and 10 variables.
#
# ## Hypotheses:
#
# - Higher carat diamonds have a higher price.
# - The cut of the diamond affects its price.
#
# ## Visualizations and Analysis:
#
# ### Box Plots:
#
# - We first plotted box plots for the carat and price variables.
# - The box plot for carat shows that the median carat value is around 0.5, with most of the data points between 0.25 and 1.2 carats.
# - The box plot for price shows that the median price is around $5000, with most of the data points between $1000 and $10,000.
# - The box plots confirm our hypothesis that higher carat diamonds have a higher price.
#
# ### Histograms:
#
# - We plotted histograms for carat and price variables.
# - The histogram for carat shows that the most common carat value is around 0.3, with a right-skewed distribution.
# - The histogram for price shows that the most common price is around $500, with a right-skewed distribution
# - These histograms also confirm our hypothesis that higher carat diamonds have a higher price.
#
# ### 3D Scatter Plots:
#
# - We created 3D scatter plots for carat, price, and depth variables.
# - The scatter plot shows that the diamonds with higher carat and price values have a deeper depth.
# - This indicates that depth might play a role in determining the price of the diamond.
#
# ### Heat Maps:
#
# - We created a heat map for carat, price, and depth variables.
# - The heat map shows that there is a positive correlation between carat and price variables, and a negative correlation between depth and price variables.
# - This confirms our hypothesis that the cut of the diamond affects its price.
#
# ### Density Plots:
#
# - We plotted density plots for carat and price variables.
# - The density plot for carat shows that most of the diamonds have a carat value between 0.2 and 1.5.
# - The density plot for price shows that most of the diamonds have a price between $1000 and $8000.
#
# ### Conclusion:
#
# - In conclusion, for this extension, I have analyzed the diamonds dataset using various visualization techniques such as box plots, histograms, 3D scatter plots, heat maps, and density plots.
# - I identified patterns and relationships among the variables and confirmed our hypotheses that higher carat diamonds have a higher price and the cut of the diamond affects its price.
# - These findings can be useful in the diamond industry for pricing and valuation of diamonds.
